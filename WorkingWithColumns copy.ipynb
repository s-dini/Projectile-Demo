# %%
# Arshea
# Period 5 AI CONCEPTS

# %%
import pandas as pd

# data using a dictionary
data = {"mammal": ["African Elephant", "Bottlenose Dolphin", "Cheetah", "Domestic Cat", "Giraffe", "Ground Squirrel", "Horse", "House Mouse", "Human", "Killer Whale", "Lion", "Pig", "Rabbit"],
        "life_span": [70, 25, 14, 16, 25, 9, 25, 3, 80, 50, 15, 10, 5],
        "hours_of_sleep": [3, 5, 12, 12, 2, 15, 3, 12, 8, 3, 20, 8, 11],
        "speed": [40, 37, 110, 50, 50, 19, 69, 13, 45, 48, 80, 18, 56],
        "diet": ["plants", "meat", "meat", "meat", "plants", "both", "plants", "both", "both", "meat", "meat", "both", "plants"]
    }

# format data into a DataFrame, basically just the code version of a spreadsheet
mammals = pd.DataFrame(data)

# prints the hours of sleep column
print("Hours of Sleep Column ONLY")
print("-----------------")
print(mammals["hours_of_sleep"])

# prints the mammal and hours of sleep columns
print()
print("Mammal and Hours of Sleep Columns")
print("-----------------")
print(mammals[["mammal", "hours_of_sleep"]])

# stores the mammals and hours of sleep columns in a variable
sleep_data = mammals[["mammal", "hours_of_sleep"]]

# prints the sleep_data for mammals who sleep exactly 8 hours
print()
print("Sleeps 8 Hours")
print("-----------------")
print(sleep_data[sleep_data["hours_of_sleep"] == 8])

# prints the sleep_data for mammals who sleep less than 4 hours
print()
print("Sleeps Less Than 4 Hours")
print("-----------------")
print(sleep_data[sleep_data["hours_of_sleep"] < 4])


# prints the sleep_data for mammals who sleep exactly 8 hours OR
# less than 4 hours
print()
print("Sleeps 8 Hours OR Less Than 4 Hours")
print("-----------------")
print(sleep_data[(sleep_data["hours_of_sleep"] == 8) |
                 (sleep_data["hours_of_sleep"] < 4)])
# Out:
# Hours of Sleep Column ONLY
# -----------------
# 0      3
# 1      5
# 2     12
# 3     12
# 4      2
# 5     15
# 6      3
# 7     12
# 8      8
# 9      3
# 10    20
# 11     8
# 12    11
# Name: hours_of_sleep, dtype: int64
#
# Mammal and Hours of Sleep Columns
# -----------------
#                 mammal  hours_of_sleep
# 0     African Elephant               3
# 1   Bottlenose Dolphin               5
# 2              Cheetah              12
# 3         Domestic Cat              12
# 4              Giraffe               2
# 5      Ground Squirrel              15
# 6                Horse               3
# 7          House Mouse              12
# 8                Human               8
# 9         Killer Whale               3
# 10                Lion              20
# 11                 Pig               8
# 12              Rabbit              11
#
# Sleeps 8 Hours
# -----------------
#    mammal  hours_of_sleep
# 8   Human               8
# 11    Pig               8
#
# ...

# %%
#Now try to perform the below taks using what you learned from the example. For this activity you will use the cereal dataset. 
#Try to format the output the same as the example too.

# %%
import pandas as pd

# Load the dataset, includes creating a dataset probably 
cereals = pd.read_csv("cereal.csv")

#print the name column only
print("Name Column ONLY")
print("-----------------")
print(cereals["name"])

#print the name and calories column 
print()
print("Names and calories")
print("-----------------")
print(cereals[["name", "calories"]])

#store the name and calories column in a variable
cal_data = cereals[["name", "calories"]]

#print all of the nutritional data for cereals who have between 85 and 115 calories
print()
print("Cereals with Calories Between 85 and 115")
print("-----------------")
print(cereals[(cereals["calories"] > 85) &
                 (cereals["calories"] < 115)])

print()

#print all of the nutritional data for cereals who have <=70 calories and they have a rating between 20 and 40. '''
print("Cereals with <=70 Calories and Rating Between 20 and 40")
print("-----------------")

print(cereals.loc[(cereals["ratings"] <= 40) & 
                  (cereals["ratings"] >= 20) & 
                  (cereals["calories"] <= 70)])
# Out:
# Name Column ONLY
# -----------------
# 0                     100% Bran
# 1             100% Natural Bran
# 2                      All-Bran
# 3     All-Bran with Extra Fiber
# 4                Almond Delight
#                 ...
# 72                      Triples
# 73                         Trix
# 74                   Wheat Chex
# 75                     Wheaties
# 76          Wheaties Honey Gold
# Name: name, Length: 77, dtype: object
#
# Names and calories
# -----------------
#                          name  calories
# 0                   100% Bran        70
# 1           100% Natural Bran       120
# 2                    All-Bran        70
# 3   All-Bran with Extra Fiber        50
# 4              Almond Delight       110
# ..                        ...       ...
# 72                    Triples       110
# 73                       Trix       110
# 74                 Wheat Chex       100
# 75                   Wheaties       100
# 76        Wheaties Honey Gold       110
#
# ...

# %%
#Your output should look something like this (although the formatting may be different):

# %%
'''
Name Column ONLY
-----------------
0                     100% Bran
1             100% Natural Bran
2                      All-Bran
3     All-Bran with Extra Fiber
4                Almond Delight
                ...            
72                      Triples
73                         Trix
74                   Wheat Chex
75                     Wheaties
76          Wheaties Honey Gold
Name: name, Length: 77, dtype: object

Name and Calories Columns
-----------------
                         name  calories
0                   100% Bran        70
1           100% Natural Bran       120
2                    All-Bran        70
3   All-Bran with Extra Fiber        50
4              Almond Delight       110
..                        ...       ...
72                    Triples       110
73                       Trix       110
74                 Wheat Chex       100
75                   Wheaties       100
76        Wheaties Honey Gold       110

[77 rows x 2 columns]

Cereals with Calories Between 85 and 115
-----------------
                           name mfr type  calories  protein  fat  sodium  \
4                Almond Delight   R    C       110        2    2     200   
5       Apple Cinnamon Cheerios   G    C       110        2    2     180   
6                   Apple Jacks   K    C       110        2    0     125   
8                     Bran Chex   R    C        90        2    1     200   
9                   Bran Flakes   P    C        90        3    0     210   
11                     Cheerios   G    C       110        6    2     290   
13                     Clusters   G    C       110        3    2     140   
14                  Cocoa Puffs   G    C       110        1    1     180   
15                    Corn Chex   R    C       110        2    0     280   
16                  Corn Flakes   K    C       100        2    0     290   
17                    Corn Pops   K    C       110        1    0      90   
18                Count Chocula   G    C       110        1    1     180   
19           Cracklin' Oat Bran   K    C       110        3    3     140   
20       Cream of Wheat (Quick)   N    H       100        3    0      80   
21                      Crispix   K    C       110        2    0     220   
22       Crispy Wheat & Raisins   G    C       100        2    1     140   
23                  Double Chex   R    C       100        2    0     190   
24                  Froot Loops   K    C       110        2    1     125   
25               Frosted Flakes   K    C       110        1    0     200   
26          Frosted Mini-Wheats   K    C       100        3    0       0   
29               Fruity Pebbles   P    C       110        1    1     135   
30                 Golden Crisp   P    C       100        2    0      45   
31               Golden Grahams   G    C       110        1    1     280   
32            Grape Nuts Flakes   P    C       100        3    1     140   
33                   Grape-Nuts   P    C       110        3    0     170   
# ...

# %%
#Now that you know how to retrieve data from columns, let's try something new. 
#We are going to modify the index of the columns. 
#Take a look at the example below:

# %%
import pandas as pd

# data using a dictionary
data = {"mammal": ["African Elephant", "Bottlenose Dolphin", "Cheetah", "Domestic Cat", "Giraffe", "Ground Squirrel", "Horse", "House Mouse", "Human", "Killer Whale", "Lion", "Pig", "Rabbit"],
        "life_span": [70, 25, 14, 16, 25, 9, 25, 3, 80, 50, 15, 10, 5],
        "hours_of_sleep": [3, 5, 12, 12, 2, 15, 3, 12, 8, 3, 20, 8, 11],
        "speed": [40, 37, 110, 50, 50, 19, 69, 13, 45, 48, 80, 18, 56],
        "diet": ["plants", "meat", "meat", "meat", "plants", "both", "plants", "both", "both", "meat", "meat", "both", "plants"]
    }

# format data into a DataFrame
mammals = pd.DataFrame(data)

# prints the mammals dataframe
print("Mammals DataFrame with Default Index")
print("-----------------")
print(mammals)

# prints the mammals dataframe using the mammal column as the index
print()
print("Mammals DataFrame with Index = Mammals Column")
print("-----------------")
print(mammals.set_index("mammal"))

# prints the mammals datafram (index didn't change)
print()
print("Didn't actually change the DataFrame...")
print("-----------------")
print(mammals)

# changes the index to the mammal column 
# prints the NEW mammals dataframe
print()
print("DOES change the DataFrame...")
print("-----------------")
mammals.set_index("mammal", inplace=True)
print(mammals)

# stores the table consisting of only the hours of sleep 
# columns in a variable
sleep_data = mammals[["hours_of_sleep"]]

# prints the sleep_data for mammals who sleep less than 4 hours
print()
print("Sleeps Less Than 4 Hours")
print("-----------------")
new_data = sleep_data[(sleep_data["hours_of_sleep"] < 4)]
print(new_data)

# resets the index by renumbering the rows
print()
print("Renumbers the Rows")
print("-----------------")
new_data.reset_index(inplace=True)
print(new_data)
# Out:
# Mammals DataFrame with Default Index
# -----------------
#                 mammal  life_span  hours_of_sleep  speed    diet
# 0     African Elephant         70               3     40  plants
# 1   Bottlenose Dolphin         25               5     37    meat
# 2              Cheetah         14              12    110    meat
# 3         Domestic Cat         16              12     50    meat
# 4              Giraffe         25               2     50  plants
# 5      Ground Squirrel          9              15     19    both
# 6                Horse         25               3     69  plants
# 7          House Mouse          3              12     13    both
# 8                Human         80               8     45    both
# 9         Killer Whale         50               3     48    meat
# 10                Lion         15              20     80    meat
# 11                 Pig         10               8     18    both
# 12              Rabbit          5              11     56  plants
#
# ...

# %%
#Now try it on your own with cereal.csv again.

# %%
import pandas as pd

# Load the dataset
cereals = pd.read_csv("cereal.csv")


# 1. Print the original cereals DataFrame with the default index

print("1. Original cereals DataFrame with the default index")
print("----------------------------------------------------")
print(cereals)
print()
print()


# 2. Print the cereals DataFrame with 'name' as the index (temporary change)

print("2. Cereals DataFrame with 'name' as the index ")
print("----------------------------------------------------")
print(cereals.set_index("name"))
print()
print()

# 3. Print the original cereals DataFrame again to show that the index didn't actually change

print("3. Original cereals DataFrame again")
print("----------------------------------------------------")
print(cereals)
print()
print()

# 4. Set the 'name' column as the index permanently and print the new DataFrame

cereals.set_index("name", inplace=True)

# 5. Store the 'calories' and 'rating' columns in a variable

nutrition_data = cereals[["calories", "rating"]]


# 6. Filter and print cereals with calories greater than 110

print("6. Cereals with calories greater than 110")
print("----------------------------------------------------")
high_calorie_cereals = nutrition_data[nutrition_data["calories"] > 110]
print(high_calorie_cereals)
print()
print()

# 7. Reset the index and print the DataFrame with default numbering

print("7. Reset index")
print("----------------------------------------------------")
high_calorie_cereals.reset_index(inplace=True)
print(high_calorie_cereals)
print()
print()
# Out:
# 1. Original cereals DataFrame with the default index
# ----------------------------------------------------
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# ...

# %%
#Your answer should look something like this:

# %%
'''
Cereals DataFrame with Default Index
-----------------
                         name mfr type  calories  protein  fat  sodium  fiber  \
0                   100% Bran   N    C        70        4    1     130   10.0   
1           100% Natural Bran   Q    C       120        3    5      15    2.0   
2                    All-Bran   K    C        70        4    1     260    9.0   
3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0   
4              Almond Delight   R    C       110        2    2     200    1.0   
..                        ...  ..  ...       ...      ...  ...     ...    ...   
72                    Triples   G    C       110        2    1     250    0.0   
73                       Trix   G    C       110        1    1     140    0.0   
74                 Wheat Chex   R    C       100        3    1     230    3.0   
75                   Wheaties   G    C       100        3    1     200    3.0   
76        Wheaties Honey Gold   G    C       110        2    1     200    1.0   

    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  
0     5.0       6     280        25      3     1.0  0.33  68.402973  
1     8.0       8     135         0      3     1.0  1.00  33.983679  
2     7.0       5     320        25      3     1.0  0.33  59.425505  
3     8.0       0     330        25      3     1.0  0.50  93.704912  
4    14.0       8      -1        25      3     1.0  0.75  34.384843  
..    ...     ...     ...       ...    ...     ...   ...        ...  
72   21.0       3      60        25      3     1.0  0.75  39.106174  
73   13.0      12      25        25      2     1.0  1.00  27.753301  
74   17.0       3     115        25      1     1.0  0.67  49.787445  
75   17.0       3     110        25      1     1.0  1.00  51.592193  
76   16.0       8      60        25      1     1.0  0.75  36.187559  

[77 rows x 16 columns]

Cereals DataFrame with Index = Name Column (Temporary)
-----------------
                          mfr type  calories  protein  fat  sodium  fiber  \
name                                                                        
100% Bran                   N    C        70        4    1     130   10.0   
100% Natural Bran           Q    C       120        3    5      15    2.0   
All-Bran                    K    C        70        4    1     260    9.0   
All-Bran with Extra Fiber   K    C        50        4    0     140   14.0   
Almond Delight              R    C       110        2    2     200    1.0   
...                        ..  ...       ...      ...  ...     ...    ...   
Triples                     G    C       110        2    1     250    0.0   
Trix                        G    C       110        1    1     140    0.0   
Wheat Chex                  R    C       100        3    1     230    3.0   
Wheaties                    G    C       100        3    1     200    3.0   
Wheaties Honey Gold         G    C       110        2    1     200    1.0   

                           carbo  sugars  potass  vitamins  shelf  weight  \
name                                                                        
100% Bran                    5.0       6     280        25      3     1.0   
100% Natural Bran            8.0       8     135         0      3     1.0   
All-Bran                     7.0       5     320        25      3     1.0   
All-Bran with Extra Fiber    8.0       0     330        25      3     1.0   
Almond Delight              14.0       8      -1        25      3     1.0   
...                          ...     ...     ...       ...    ...     ...   
Triples                     21.0       3      60        25      3     1.0   
Trix                        13.0      12      25        25      2     1.0   
Wheat Chex                  17.0       3     115        25      1     1.0   
Wheaties                    17.0       3     110        25      1     1.0   
Wheaties Honey Gold         16.0       8      60        25      1     1.0   

                           cups     rating  
name                                        
100% Bran                  0.33  68.402973  
100% Natural Bran          1.00  33.983679  
All-Bran                   0.33  59.425505  
All-Bran with Extra Fiber  0.50  93.704912  
Almond Delight             0.75  34.384843  
...                         ...        ...  
Triples                    0.75  39.106174  
Trix                       1.00  27.753301  
Wheat Chex                 0.67  49.787445  
Wheaties                   1.00  51.592193  
Wheaties Honey Gold        0.75  36.187559  

[77 rows x 15 columns]

Didn't actually change the DataFrame...
-----------------
                         name mfr type  calories  protein  fat  sodium  fiber  \
0                   100% Bran   N    C        70        4    1     130   10.0   
1           100% Natural Bran   Q    C       120        3    5      15    2.0   
2                    All-Bran   K    C        70        4    1     260    9.0   
3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0   
4              Almond Delight   R    C       110        2    2     200    1.0   
..                        ...  ..  ...       ...      ...  ...     ...    ...   
72                    Triples   G    C       110        2    1     250    0.0   
73                       Trix   G    C       110        1    1     140    0.0   
74                 Wheat Chex   R    C       100        3    1     230    3.0   
75                   Wheaties   G    C       100        3    1     200    3.0   
76        Wheaties Honey Gold   G    C       110        2    1     200    1.0   

    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  
0     5.0       6     280        25      3     1.0  0.33  68.402973  
1     8.0       8     135         0      3     1.0  1.00  33.983679  
2     7.0       5     320        25      3     1.0  0.33  59.425505  
3     8.0       0     330        25      3     1.0  0.50  93.704912  
4    14.0       8      -1        25      3     1.0  0.75  34.384843  
..    ...     ...     ...       ...    ...     ...   ...        ...  
72   21.0       3      60        25      3     1.0  0.75  39.106174  
73   13.0      12      25        25      2     1.0  1.00  27.753301  
74   17.0       3     115        25      1     1.0  0.67  49.787445  
75   17.0       3     110        25      1     1.0  1.00  51.592193  
76   16.0       8      60        25      1     1.0  0.75  36.187559  

[77 rows x 16 columns]

DOES change the DataFrame (Permanently)...
-----------------
                          mfr type  calories  protein  fat  sodium  fiber  \
name                                                                        
100% Bran                   N    C        70        4    1     130   10.0   
100% Natural Bran           Q    C       120        3    5      15    2.0   
All-Bran                    K    C        70        4    1     260    9.0   
All-Bran with Extra Fiber   K    C        50        4    0     140   14.0   
Almond Delight              R    C       110        2    2     200    1.0   
...                        ..  ...       ...      ...  ...     ...    ...   
Triples                     G    C       110        2    1     250    0.0   
Trix                        G    C       110        1    1     140    0.0   
Wheat Chex                  R    C       100        3    1     230    3.0   
Wheaties                    G    C       100        3    1     200    3.0   
Wheaties Honey Gold         G    C       110        2    1     200    1.0   

                           carbo  sugars  potass  vitamins  shelf  weight  \
name                                                                        
100% Bran                    5.0       6     280        25      3     1.0   
100% Natural Bran            8.0       8     135         0      3     1.0   
All-Bran                     7.0       5     320        25      3     1.0   
All-Bran with Extra Fiber    8.0       0     330        25      3     1.0   
Almond Delight              14.0       8      -1        25      3     1.0   
...                          ...     ...     ...       ...    ...     ...   
Triples                     21.0       3      60        25      3     1.0   
Trix                        13.0      12      25        25      2     1.0   
Wheat Chex                  17.0       3     115        25      1     1.0   
Wheaties                    17.0       3     110        25      1     1.0   
Wheaties Honey Gold         16.0       8      60        25      1     1.0   

                           cups     rating  
name                                        
100% Bran                  0.33  68.402973  
100% Natural Bran          1.00  33.983679  
All-Bran                   0.33  59.425505  
All-Bran with Extra Fiber  0.50  93.704912  
Almond Delight             0.75  34.384843  
...                         ...        ...  
Triples                    0.75  39.106174  
Trix                       1.00  27.753301  
Wheat Chex                 0.67  49.787445  
Wheaties                   1.00  51.592193  
Wheaties Honey Gold        0.75  36.187559  

[77 rows x 15 columns]

Cereals with Calories > 110
-----------------
                                        calories     rating
name                                                       
100% Natural Bran                            120  33.983679
Basic 4                                      130  37.038562
Cap'n'Crunch                                 120  18.042851
Cinnamon Toast Crunch                        120  19.823573
Fruit & Fibre Dates; Walnuts; and Oats       120  40.917047
Fruitful Bran                                120  41.015492
Great Grains Pecan                           120  45.811716
Honey Graham Ohs                             120  21.871292
Just Right Fruit & Nut                       140  36.471512
Muesli Raisins; Dates; & Almonds             150  37.136863
Muesli Raisins; Peaches; & Pecans            150  34.139765
Mueslix Crispy Blend                         160  30.313351
Nut&Honey Crunch                             120  29.924285
Nutri-Grain Almond-Raisin                    140  40.692320
Oatmeal Raisin Crisp                         130  30.450843
Post Nat. Raisin Bran                        120  37.840594
Raisin Bran                                  120  39.259197
Total Raisin Bran                            140  28.592785

Reset Index to Default (Renumbering Rows)
-----------------
                                      name  calories     rating
0                        100% Natural Bran       120  33.983679
1                                  Basic 4       130  37.038562
2                             Cap'n'Crunch       120  18.042851
3                    Cinnamon Toast Crunch       120  19.823573
4   Fruit & Fibre Dates; Walnuts; and Oats       120  40.917047
5                            Fruitful Bran       120  41.015492
6                       Great Grains Pecan       120  45.811716
7                         Honey Graham Ohs       120  21.871292
8                   Just Right Fruit & Nut       140  36.471512
9         Muesli Raisins; Dates; & Almonds       150  37.136863
10       Muesli Raisins; Peaches; & Pecans       150  34.139765
11                    Mueslix Crispy Blend       160  30.313351
12                        Nut&Honey Crunch       120  29.924285
13               Nutri-Grain Almond-Raisin       140  40.692320
14                    Oatmeal Raisin Crisp       130  30.450843
15                   Post Nat. Raisin Bran       120  37.840594
16                             Raisin Bran       120  39.259197
17                       Total Raisin Bran       140  28.592785
'''
# Out:
# "\nCereals DataFrame with Default Index\n-----------------\n                         name mfr type  calories  protein  fat  sodium  fiber  0                   100% Bran   N    C        70        4    1     130   10.0   \n1           100% Natural Bran   Q    C       120        3    5      15    2.0   \n2                    All-Bran   K    C        70        4    1     260    9.0   \n3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0   \n4              Almond Delight   R    C       110        2    2     200    1.0   \n..                        ...  ..  ...       ...      ...  ...     ...    ...   \n72                    Triples   G    C       110        2    1     250    0.0   \n73                       Trix   G    C       110        1    1     140    0.0   \n74                 Wheat Chex   R    C       100        3    1     230    3.0   \n75                   Wheaties   G    C       100        3    1     200    3.0   \n76        Wheaties Honey Gold   G    C 
# ...
